# %%
#✅ ✅ ① setup_driver()
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

def setup_driver():
    options = webdriver.ChromeOptions()
    # 옵션 원하는 대로 추가
    options.add_argument('--start-maximized')
    driver = webdriver.Chrome(options=options)
    return driver

# %%
#✅ ✅ ② open_shorts_page()
def open_shorts_page(driver, url):
    driver.get(url)
    print(f"✅ 페이지 열림: {url}")
    time.sleep(5)

# %%
#✅ ✅ ③ click_comment_button()
def click_comment_button(driver):
    try:
        comment_button = driver.find_element(By.CSS_SELECTOR, "#comments-button")
        comment_button.click()
        print("✅ 댓글 버튼 클릭 완료")
        time.sleep(3)
    except Exception as e:
        print("❌ 댓글 버튼 클릭 실패:", e)
        raise

# %%
# ✅ ✅ ④ find_scroll_container()
def find_scroll_container(driver):
    try:
        container = driver.find_element(By.CSS_SELECTOR, "ytd-item-section-renderer #contents")
        print("✅ 댓글창 스크롤 컨테이너 찾음")
        return container
    except Exception as e:
        print("❌ 스크롤 컨테이너 못 찾음:", e)
        raise

# %%
def human_like_scroll(driver, container, wait_time=3, max_rounds=50):
    print("\n✅ 사람스러운 무한스크롤 시작")
    prev_height = driver.execute_script("return arguments[0].scrollHeight;", container)

    for i in range(max_rounds):
        print(f"👉 스크롤 {i+1}회")

        # 1. 바닥까지
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight;", container)
        print("✅ 바닥까지 스크롤")

        # 2. 기다림
        print(f"⏱️ wait {wait_time}s")
        time.sleep(wait_time)

        # 3. 높이 변화 체크
        new_height = driver.execute_script("return arguments[0].scrollHeight;", container)
        print(f"📏 scrollHeight 변화: {prev_height} -> {new_height}")

        if new_height == prev_height:
            print("✅ 더 이상 continuation 없음. 스크롤 종료.")
            break

        prev_height = new_height

    print("✅ 스크롤 루프 완료\n")

# %%
#✅ ✅ ⑥ parse_comments()
from bs4 import BeautifulSoup

def parse_comments_soup(driver):
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    results = []

    all_threads = soup.select('ytd-comment-thread-renderer')
    print(f"✅ 찾은 댓글 블록 수: {len(all_threads)}")

    for thread in all_threads:
        # AUTHOR
        author_tag = thread.select_one('a#author-text')
        if not author_tag:
            author_tag = thread.select_one('span.style-scope.ytd-comment-view-model')
        author_text = author_tag.get_text(strip=True) if author_tag else "N/A"

        # CONTENT
        content_tag = thread.select_one('yt-attributed-string#content-text')
        if not content_tag:
            content_tag = thread.select_one('span.yt-core-attributed-string')
        content_text = content_tag.get_text(strip=True) if content_tag else "N/A"

        results.append((author_text, content_text))

    print(f"✅ 파싱 완료. 총 댓글 수: {len(results)}")
    return results

# %%
#✅ ✅ ⑦ 전체 메인 플로우
if __name__ == "__main__":
    driver = setup_driver()

    # 🎯 1. 페이지 열기
    url = "https://www.youtube.com/shorts/JssAW9IruVo"
    open_shorts_page(driver, url)

    # 🎯 2. 댓글 버튼 열기
    click_comment_button(driver)

    # 🎯 3. 댓글창 스크롤 컨테이너 찾기
    container = find_scroll_container(driver)

    # 🎯 4. 스크롤 → continuation 모두 불러오기
    human_like_scroll(driver, container)

    # 🎯 5. 파싱
    comment_data = parse_comments_soup(driver)

    # 🎯 6. 출력
    for idx, (author, text) in enumerate(comment_data, start=1):
        print(f"{idx}. {author}: {text}")

    # # 🎯 7. 종료
    # driver.quit()
# Out:
# ✅ 페이지 열림: https://www.youtube.com/shorts/JssAW9IruVo
# ✅ 댓글 버튼 클릭 완료
# ✅ 댓글창 스크롤 컨테이너 찾음
#
# ✅ 사람스러운 무한스크롤 시작
# 👉 스크롤 1회
# ✅ 바닥까지 스크롤
# ⏱️ wait 3s
# 📏 scrollHeight 변화: 2616 -> 4872
# 👉 스크롤 2회
# ✅ 바닥까지 스크롤
# ⏱️ wait 3s
# 📏 scrollHeight 변화: 4872 -> 7032
# 👉 스크롤 3회
# ✅ 바닥까지 스크롤
# ⏱️ wait 3s
# 📏 scrollHeight 변화: 7032 -> 9400
# 👉 스크롤 4회
# ✅ 바닥까지 스크롤
# ⏱️ wait 3s
# 📏 scrollHeight 변화: 9400 -> 9098
# 👉 스크롤 5회
# ✅ 바닥까지 스크롤
# ⏱️ wait 3s
# 📏 scrollHeight 변화: 9098 -> 9098
# ✅ 더 이상 continuation 없음. 스크롤 종료.
# ✅ 스크롤 루프 완료
#
# ✅ 찾은 댓글 블록 수: 81
# ✅ 파싱 완료. 총 댓글 수: 81
# 1. @내일보자: 찐친 특) 평소에 안 꾸미고 만남
# 칭찬은 해줘도 셀프 칭찬은 짜증남ㅋㅋㅋ: https://weverse.io/gidle/live/3-159392585
# 2. @Queenelmo: 메건을 킹받게하는 사람 이거 귀하거든요ㅋㅋㅋㅋㅋㅋㅋ
# 3. @jadongchamolggoya: 둘 다 성격 너무 좋다 ㅋㅋ
# 4. @민_져니: ㅋㅋ둘이 친한거 진짜 너무 죠아
# 5. @이연후-h3i: 헐 미연지원 친한지 처음 알았는데 그림체 진짜 잘 어울린다.. 순정만화 토끼상 여주 st
# 6. @moosic_is_my_life: 플로버만 있었으면 비방용 언어 나왔다ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 7. @WooooYoung: 참지 못한 메건 ㅋㅋㅋ
# 8. @미연공주-w8z: 쿼카 메건은 사랑이지
# 9. @moooon.chill3080: 며니 사랑행
# 10. @van_oranje: 진짜 너어무 예쁘다
# 11. @대이브: 사랑해요 메건
# 12. @또가리-i6u: 요란한 메건을 잠재울 수 있는 미연이ㅋㅋㅋ
# 13. @바퀴걸레-o3m: 2대 비주얼메보
# 14. @라시얀: 박규리의 의지를 잇는 미연..
# 15. @noodle0502: 조면 미쳤다...쇼츠 내리는데 보자마자 와 소리나오네
# 16. @JhL-xz6nh: 웃기시던데요  ㅋ
# 17. @t-j5q: 예쁜이 옆에 예쁜이둘다 너무 예쁘다 미연 지원 너무 좋아!!
# 18. @윤재영-w9i: 한수위를 만나니까 얌전해진 메건ㅋㅋㅋㅋ
# 19. @Hwang-Jung-Sik: 우리 메거니 배운거였구나? ㅋ
# 20. @puppy-p8b7w: 개이쁘다
# 21. @sbgjgg.bssggdl-i5f: 면은 세계관 최상위 포식자임
# 22. @현종윤-r5t: 여친 여치니 이두명 제대로임
# 23. @B29-p2n: 맞아요.
# 사람은 좌우 완벽대칭은 없습니다.
# 눈,귀,볼,눈썹,엉덩이,손,팔,발,다리등 다 미묘하게  짝짝이 입니다.
#
# 그래도 미연님은 겁~~~~네 예쁩니다! 심지어  항상 이쁘죠.
# 24. @이정진-n9n: 미연아가 너무 이쁘잖아
# 25. @네버버_플로버: 본진과 본진의 만남이란 사랑입니다
# 26. @쒄샤인: ㅋㅋㅋㅋㅋㅋ 킹받는다의 표본
# 27. @이형운-w9m: 초반부터 얼굴 공격 장난아니네
# 28. @ShiningBANGstar: 좋아 미연 매건
# 29. @pain-complete: TMI : 메건과 면은 10년 넘게 알아온 언니,동생 사이 겸 친구사이 이다. 보컬 아이돌학교 입학전에도 둘이 보컬 학원도 같이 다녀서 친분이 꽤 깊다.
# 30. @thenewh9175: 이거야말로 미지의 세계구만
# 31. @김미국-g6o: 아니 미연옆에 지원? 미쳤다 진짜
# 32. @김기성-p4o: 짝짝이여 이뿌다 천년의미연
# 33. @user-gl6su6kk9q: 여기에 츄까지 있으면... 어후
# 텐션 어쩔?
# 34. @ORIGIN11111: 미연은 악플러들이 없는 이유:아무리 개킹받게  발악해도 타격이 전혀 없음 악플러들 지쳐버림
# 35. @키다리아저씨-s2g: 존예
# 36. @The_most_dangerous_bug: (대충 송하영이 마! 하고 소리지르는 짤)
# 37. @안혁찬-v6f: 이뻐서 할말이 없다
# 38. @리락이귀여운: 미연은 늘 이쁘지 ㅋ
# 39. @둥근네모네모: ’미‘ 자 들어가는 사람들 지원 킹받게 잘하네 ㅋㅋㅋㅋㅋㅋ 미연 미미미누
# 40. @choidanes3419: 미러전
# 41. @user-y950: 비주얼 은혜로운거 봐라 ㄷㄷ
# 42. @엄근진: 근데 예쁘긴해 ㅇㅈ
# 43. @킁-7: 미연도 아이돌 미모 탑라인에 들어갈만 하지않나요
# 44. @wksehatm: 아니 메건 진짜 이쁜거였네
# 맨날 뛰뛰빵빵 같은거 해서 체감이 안됐는데
# 미연 옆에서 안꿀리네ㄷㄷ
# 45. @user-tn8cq8fx33k: 쿼카 vs 극딜러
# 46. @gwalstn: 딴거보다 박지원 봐서 너무 좋다. 근데 확실히 멤버들이랑 반응이 다른게, 미연한테 동조해줌. 멤버였으면 이미 가루가 되도록 딜을 넣다 반격 맞고 딸피 됐겠지(fest. 하영, 채영)
# 47. @damien4621: 오랜만에....'한따까리 할까'
# 48. @kxm_12: my jiwon so funny
# 49. @너만을면랑해: 조미연 넌 항상 예뿌자나..
# 50. @nishitripathi2319: Babyfriend️ Miyeon️, youare so pretty cute and very beautiful️. Loveyou🇮🇳.
# 51. @LC-bi7lp: 프롬 멤버들 중에 한 명이 저랬으면 바로 온갖 곳에서 딜 넣기 바쁜 동족 상잔이었다...
# 52. @안유진-k9g: 여윽시 조면!~^^
# 53. @개냐옹이: 나두 짜증나고싶다
# 54. @jimmyle9787: just sit & stand there & laugh Ho Ho Ho
# 55. @LLLJHLLL: 킹받음으로 단련된 져니마저 킹받음 ㅋㅋㅋㅋㅋㅋㅋ
# 56. @김기성-p4o: 진짜짜증난다 말이귀엽네
# 57. @alexpark2813:
# 58. @므훗-b1x: 미연이네
# 59. @어제와다른오늘: 우리어머니가 조미연보고 어머 엄청이쁘다고한 유일한1인
# 60. @악플보면댓글참교육: 공주병 메건이 혀를 내두를 정도면 ㅋㅋㅋ
# 61. @Orla260: 진짜 짜증나게 귀여운데 그렇다고 짜증난다는건 아님 뭔지 알지?
# 62. @allahuakbarrr: 박지원 이 넘사벽이긴하네 ㄷㄷ
# 63. @김지은-g1c1c: 짝눈은 수술 안했다는 증거지
# 64. @sxuxnn: 옆사람 당연히 아이들 멤버일 줄 알았는데 지원이길래 잠깐 인지부조화 옴
# 65. @SUSU5112o: 맞넹 자연미인이라 글치
# 66. @누구게-d5l: 둘 다 개이쁨 지원 저 얼굴 화장 안한건데도 미연 옆에서 안꿀리면 진짜 개이쁜거임…
# 67. @20000ho: 박지원도 안 밀리네
# 68. @Ll-t5p: 근데 진짜.. 그정도까진 아닌데 왜자꾸 예쁘다고 본인입으로 그러는거지
# 69. @블루러시안: 미연 공주병 할때마다 난 카라 박규리가 생각나..ㅠ
# 70. @루비파도: 제왑은 왜 이둘을 놓친거야?
# 71. @운동인-t3q: 미연은 좋게 봤었는데 연기대상 축하무대에서 노래 부르는거 보고 진짜 오만정 다 떨어졌음!!아니 못해도 어느정도껏 못해야될거아냐~!난 그리고 얘가 노래 잘하는줄 알고 있었어서 충격이 더했음!ㅜㅜ
# 72. @김재윤-w9r: 얘 왜자꾸 뜨ㅣㅓ유쟈냐
# 73. @아라베스크죠둥이: 이거 진짜러 같이 라에브 한건가요???
# 74. @푸른늑대-r5x: 레알 공주병.지도 지가 예쁜걸 알고있음.ㅋㅋ
# 75. @user-jjong1: 예쁜건 반박 할 수 없어서 더열받
# 76. @WILDSONE: 눈 짝짝이지 박수 짝짝 ㅇㅇㅋ
# 77. @해파리1: ㅋ
# 78. @JjKk-qd7ds: 둘이 어케 만났지
# 79. @user-jt7li7mq1p: 어지간히 해라. 자꾸 저러닌깐 짜증나긴 함.
# 80. @더불렉179번: 나댈정도로 안이쁜데 너무 나데니깐 꼴보기 싫음
# 81. @donghyunroh9069: 짝짝이가  더 이쁘네
